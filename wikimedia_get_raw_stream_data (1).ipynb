# %%
# Install libs not already included in instance
# %pip install requests-sse
# %pip install pywikibot
# %restart_python
# Out:
# Requirement already satisfied: requests-sse in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1a8f3ca0-6a22-4792-b8a2-4c982e19e32a/lib/python3.12/site-packages (0.5.2)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /databricks/python3/lib/python3.12/site-packages (from requests-sse) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests<3.0.0,>=2.0.0->requests-sse) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests<3.0.0,>=2.0.0->requests-sse) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.12/site-packages (from requests<3.0.0,>=2.0.0->requests-sse) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests<3.0.0,>=2.0.0->requests-sse) (2025.1.31)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: pywikibot in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1a8f3ca0-6a22-4792-b8a2-4c982e19e32a/lib/python3.12/site-packages (10.7.0)
# Requirement already satisfied: mwparserfromhell>=0.5.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-1a8f3ca0-6a22-4792-b8a2-4c982e19e32a/lib/python3.12/site-packages (from pywikibot) (0.7.2)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.12/site-packages (from pywikibot) (24.1)
# Requirement already satisfied: requests>=2.31.0 in /databricks/python3/lib/python3.12/site-packages (from pywikibot) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.31.0->pywikibot) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.31.0->pywikibot) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.31.0->pywikibot) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.31.0->pywikibot) (2025.1.31)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import json
import os
from pywikibot.comms.eventstreams import EventStreams
from datetime import datetime, timedelta

# %%
# Define the name of the new uc_catalog
uc_catalog = 'wikimedia_db'
spark.sql('create catalog if not exists ' + uc_catalog)

# define the raw events schema
uc_schema_raw_events = 'raw_events'
spark.sql('create schema if not exists ' + uc_catalog + '.' + uc_schema_raw_events)

# save the volume time
tmp_volume_time = datetime.now()
tmp_volume =  f"events_tmp_{tmp_volume_time.strftime('%y_%m_%d')}"
spark.sql('create volume if not exists ' + uc_catalog + '.' + uc_schema_raw_events + '.' + tmp_volume)
# Out:
# DataFrame[]

# %%
# Create uc last_event_cache schema and volume if not exists
uc_schema_last_event_cache = 'last_event_cache'
spark.sql('create schema if not exists ' + uc_catalog + '.' + uc_schema_last_event_cache)

last_event_cache_volume = 'data'
spark.sql('create volume if not exists ' + uc_catalog + '.' + uc_schema_last_event_cache + '.' + last_event_cache_volume)
# Out:
# DataFrame[]

# %%
# simple helper function for checking if a file exists
def check_file_exists(last_event_cache_path: str) -> bool:
    return os.path.exists(last_event_cache_path)

# set stream object to start from  7 days ago on first run
# and then from the last event id on subsequent runs
def set_stream(last_event_cache_path: str, start_time: datetime) -> EventStreams:
    if not check_file_exists(last_event_cache_path):
        # start from 7 days ago
        stream_start_date_raw = start_time - timedelta(days=8)
        stream_start_date_formatted = stream_start_date_raw.strftime('%Y%m%d')
        return EventStreams(streams=["recentchange", "revision-create"], since=stream_start_date_formatted)
    else:
        # start from last event id
        with open(last_event_cache_path, 'r') as f:
            last_time_stamp = f.read()
            return EventStreams(streams=["recentchange", "revision-create"], since=last_time_stamp)

# %%
# set start time for streaming and temp voume naming
start_time = datetime.now()

# set stop time for streaming
duration = .5
stop_time = start_time + timedelta(minutes=duration)

# set last_event_cache path
last_event_cache_path = f"/Volumes/{uc_catalog}/{uc_schema_last_event_cache}/{last_event_cache_volume}/last_event_cache.txt"

# create the streaming object
stream = set_stream(last_event_cache_path, start_time)

# %%
tmp_stream = set_stream(last_event_cache_path, start_time)

for i in range(5):
    event = next(tmp_stream)
    print(json.dumps(event, indent=2))
# Out:
# {
#   "$schema": "/mediawiki/recentchange/1.0.0",
#   "meta": {
#     "uri": "https://ar.wikipedia.org/wiki/%D8%AE%D8%A7%D8%B5:%D8%AF%D8%AE%D9%88%D9%84_%D8%A7%D9%84%D9%85%D8%B3%D8%AA%D8%AE%D8%AF%D9%85",
#     "request_id": "63249159-52e2-4dc3-8a64-9325542535ac",
#     "id": "604c6a76-ee54-41f9-bd71-6c3e0563d441",
#     "domain": "ar.wikipedia.org",
#     "stream": "mediawiki.recentchange",
#     "dt": "2025-11-09T18:49:44.795Z",
#     "topic": "eqiad.mediawiki.recentchange",
#     "partition": 0,
#     "offset": 5960682412
#   },
#   "type": "log",
#   "namespace": -1,
#   "title": "\u062e\u0627\u0635:\u062f\u062e\u0648\u0644 \u0627\u0644\u0645\u0633\u062a\u062e\u062f\u0645",
#   "title_url": "https://ar.wikipedia.org/wiki/%D8%AE%D8%A7%D8%B5:%D8%AF%D8%AE%D9%88%D9%84_%D8%A7%D9%84%D9%85%D8%B3%D8%AA%D8%AE%D8%AF%D9%85",
#   "comment": "",
#   "timestamp": 1762714184,
#   "user": "NoWwWeR",
#   "bot": false,
#   "log_id": 0,
#   "log_type": "abusefilter",
#   "log_action": "hit",
#   "log_params": {
#     "action": "autocreateaccount",
#     "filter": "89",
#     "actions": "warn",
#     "log": 10732786
#   },
#   "log_action_comment": "NoWwWeR  \u0623\u0637\u0644\u0642 [[\u062e\u0627\u0635:\u0645\u0631\u0634\u062d \u0627\u0644\u0625\u0633\u0627\u0621\u0629/89|\u0627\u0644\u0645\u0631\u0634\u062d 89]]; \u0645\u0624\u062f\u064a\u0627 \u0627\u0644\u0641\u0639\u0644 \"autocreateaccount\" \u0641\u064a [[\u062e\u0627\u0635:\u062f\u062e\u0648\u0644 \u0627\u0644\u0645\u0633\u062a\u062e\u062f\u0645]]\u060c \u0627\u0644\u0625\u062c\u0631\u0627\u0621\u0627\u062a \u0627\u0644\u0645\u062a\u062e\u0630\u0629: \u062a\u062d\u0630\u064a\u0631 ([[\u062e\u0627\u0635:\u0633\u062c\u0644 \u0627\u0644\u0625\u0633\u0627\u0621\u0629/10732786|\u0627\u0644\u062a\u0641\u0627\u0635\u064a\u0644]])",
#   "server_url": "https://ar.wikipedia.org",
#   "server_name": "ar.wikipedia.org",
#   "server_script_path": "/w",
#   "wiki": "arwiki",
#   "parsedcomment": ""
# }
# {
#   "$schema": "/mediawiki/recentchange/1.0.0",
#   "meta": {
#     "uri": "https://ar.wikipedia.org/wiki/%D8%AE%D8%A7%D8%B5:%D8%AF%D8%AE%D9%88%D9%84_%D8%A7%D9%84%D9%85%D8%B3%D8%AA%D8%AE%D8%AF%D9%85",
#     "request_id": "5f7d9657-8597-46be-a3b3-21471fe0b510",
#     "id": "4c054336-b807-4078-bd24-593cc1a113bb",
#     "domain": "ar.wikipedia.org",
#     "stream": "mediawiki.recentchange",
#     "dt": "2025-11-09T18:50:59.347Z",
#     "topic": "eqiad.mediawiki.recentchange",
#     "partition": 0,
#     "offset": 5960682413
#   },
#   "type": "log",
#   "namespace": -1,
#   "title": "\u062e\u0627\u0635:\u062f\u062e\u0648\u0644 \u0627\u0644\u0645\u0633\u062a\u062e\u062f\u0645",
#   "title_url": "https://ar.wikipedia.org/wiki/%D8%AE%D8%A7%D8%B5:%D8%AF%D8%AE%D9%88%D9%84_%D8%A7%D9%84%D9%85%D8%B3%D8%AA%D8%AE%D8%AF%D9%85",
#   "comment": "",
#   "timestamp": 1762714259,
#   "user": "NoWwWeR",
#   "bot": false,
#   "log_id": 0,
#   "log_type": "abusefilter",
#   "log_action": "hit",
#   "log_params": {
#     "action": "autocreateaccount",
#     "filter": "89",
#     "actions": "warn",
#     "log": 10732787
#   },
#   "log_action_comment": "NoWwWeR  \u0623\u0637\u0644\u0642 [[\u062e\u0627\u0635:\u0645\u0631\u0634\u062d \u0627\u0644\u0625\u0633\u0627\u0621\u0629/89|\u0627\u0644\u0645\u0631\u0634\u062d 89]]; \u0645\u0624\u062f\u064a\u0627 \u0627\u0644\u0641\u0639\u0644 \"autocreateaccount\" \u0641\u064a [[\u062e\u0627\u0635:\u062f\u062e\u0648\u0644 \u0627\u0644\u0645\u0633\u062a\u062e\u062f\u0645]]\u060c \u0627\u0644\u0625\u062c\u0631\u0627\u0621\u0627\u062a \u0627\u0644\u0645\u062a\u062e\u0630\u0629: \u062a\u062d\u0630\u064a\u0631 ([[\u062e\u0627\u0635:\u0633\u062c\u0644 \u0627\u0644\u0625\u0633\u0627\u0621\u0629/10732787|\u0627\u0644\u062a\u0641\u0627\u0635\u064a\u0644]])",
#   "server_url": "https://ar.wikipedia.org",
#   "server_name": "ar.wikipedia.org",
#   "server_script_path": "/w",
#   "wiki": "arwiki",
#   "parsedcomment": ""
# }
# {
#   "$schema": "/mediawiki/recentchange/1.0.0",
#   "meta": {
#     "uri": "https://ar.wikipedia.org/wiki/%D8%AE%D8%A7%D8%B5:%D8%AF%D8%AE%D9%88%D9%84_%D8%A7%D9%84%D9%85%D8%B3%D8%AA%D8%AE%D8%AF%D9%85",
#     "request_id": "4a65ffdc-24e1-47d7-a07e-1b5bbfbc6f48",
#     "id": "bee5cfd8-57e1-47a0-bd72-8f420faad993",
#     "domain": "ar.wikipedia.org",
#     "stream": "mediawiki.recentchange",
#     "dt": "2025-11-09T18:51:32.841Z",
#     "topic": "eqiad.mediawiki.recentchange",
#     "partition": 0,
#     "offset": 5960682414
#   },
#   "type": "log",
#   "namespace": -1,
#   "title": "\u062e\u0627\u0635:\u062f\u062e\u0648\u0644 \u0627\u0644\u0645\u0633\u062a\u062e\u062f\u0645",
#   "title_url": "https://ar.wikipedia.org/wiki/%D8%AE%D8%A7%D8%B5:%D8%AF%D8%AE%D9%88%D9%84_%D8%A7%D9%84%D9%85%D8%B3%D8%AA%D8%AE%D8%AF%D9%85",
#   "comment": "",
#   "timestamp": 1762714292,
#   "user": "Wikipirahavat",
#   "bot": false,
#   "log_id": 0,
#   "log_type": "abusefilter",
#   "log_action": "hit",
#   "log_params": {
#     "action": "autocreateaccount",
#     "filter": "89",
#     "actions": "warn",
#     "log": 10732788
#   },
#   "log_action_comment": "Wikipirahavat  \u0623\u0637\u0644\u0642 [[\u062e\u0627\u0635:\u0645\u0631\u0634\u062d \u0627\u0644\u0625\u0633\u0627\u0621\u0629/89|\u0627\u0644\u0645\u0631\u0634\u062d 89]]; \u0645\u0624\u062f\u064a\u0627 \u0627\u0644\u0641\u0639\u0644 \"autocreateaccount\" \u0641\u064a [[\u062e\u0627\u0635:\u062f\u062e\u0648\u0644 \u0627\u0644\u0645\u0633\u062a\u062e\u062f\u0645]]\u060c \u0627\u0644\u0625\u062c\u0631\u0627\u0621\u0627\u062a \u0627\u0644\u0645\u062a\u062e\u0630\u0629: \u062a\u062d\u0630\u064a\u0631 ([[\u062e\u0627\u0635:\u0633\u062c\u0644 \u0627\u0644\u0625\u0633\u0627\u0621\u0629/10732788|\u0627\u0644\u062a\u0641\u0627\u0635\u064a\u0644]])",
#   "server_url": "https://ar.wikipedia.org",
#   "server_name": "ar.wikipedia.org",
#   "server_script_path": "/w",
#   "wiki": "arwiki",
#   "parsedcomment": ""
# }
# {
#   "$schema": "/mediawiki/recentchange/1.0.0",
#   "meta": {
#     "uri": "https://ar.wikipedia.org/wiki/%D8%AE%D8%A7%D8%B5:%D8%AF%D8%AE%D9%88%D9%84_%D8%A7%D9%84%D9%85%D8%B3%D8%AA%D8%AE%D8%AF%D9%85",
#     "request_id": "38791b84-c682-43ce-a5da-cfb68cbd191b",
#     "id": "4d8afaa5-12b2-4d33-8be0-799e01fefaa9",
#     "domain": "ar.wikipedia.org",
#     "stream": "mediawiki.recentchange",
#     "dt": "2025-11-09T18:51:38.732Z",
#     "topic": "eqiad.mediawiki.recentchange",
#     "partition": 0,
#     "offset": 5960682415
#   },
#   "type": "log",
#   "namespace": -1,
#   "title": "\u062e\u0627\u0635:\u062f\u062e\u0648\u0644 \u0627\u0644\u0645\u0633\u062a\u062e\u062f\u0645",
#   "title_url": "https://ar.wikipedia.org/wiki/%D8%AE%D8%A7%D8%B5:%D8%AF%D8%AE%D9%88%D9%84_%D8%A7%D9%84%D9%85%D8%B3%D8%AA%D8%AE%D8%AF%D9%85",
#   "comment": "",
#   "timestamp": 1762714298,
#   "user": "Wikipirahavat",
#   "bot": false,
#   "log_id": 0,
#   "log_type": "abusefilter",
#   "log_action": "hit",
#   "log_params": {
#     "action": "autocreateaccount",
#     "filter": "89",
#     "actions": "warn",
#     "log": 10732789
#   },
#   "log_action_comment": "Wikipirahavat  \u0623\u0637\u0644\u0642 [[\u062e\u0627\u0635:\u0645\u0631\u0634\u062d \u0627\u0644\u0625\u0633\u0627\u0621\u0629/89|\u0627\u0644\u0645\u0631\u0634\u062d 89]]; \u0645\u0624\u062f\u064a\u0627 \u0627\u0644\u0641\u0639\u0644 \"autocreateaccount\" \u0641\u064a [[\u062e\u0627\u0635:\u062f\u062e\u0648\u0644 \u0627\u0644\u0645\u0633\u062a\u062e\u062f\u0645]]\u060c \u0627\u0644\u0625\u062c\u0631\u0627\u0621\u0627\u062a \u0627\u0644\u0645\u062a\u062e\u0630\u0629: \u062a\u062d\u0630\u064a\u0631 ([[\u062e\u0627\u0635:\u0633\u062c\u0644 \u0627\u0644\u0625\u0633\u0627\u0621\u0629/10732789|\u0627\u0644\u062a\u0641\u0627\u0635\u064a\u0644]])",
#   "server_url": "https://ar.wikipedia.org",
#   "server_name": "ar.wikipedia.org",
#   "server_script_path": "/w",
#   "wiki": "arwiki",
#   "parsedcomment": ""
# }
# {
#   "$schema": "/mediawiki/recentchange/1.0.0",
#   "meta": {
#     "uri": "https://ar.wikipedia.org/wiki/%D8%AE%D8%A7%D8%B5:%D8%AF%D8%AE%D9%88%D9%84_%D8%A7%D9%84%D9%85%D8%B3%D8%AA%D8%AE%D8%AF%D9%85",
#     "request_id": "85859cf1-dccd-43e1-bef1-b33defd88bf7",
#     "id": "155e0011-b06b-4ae1-b5a1-bb59cd194087",
#     "domain": "ar.wikipedia.org",
#     "stream": "mediawiki.recentchange",
#     "dt": "2025-11-09T18:52:13.364Z",
#     "topic": "eqiad.mediawiki.recentchange",
#     "partition": 0,
#     "offset": 5960682416
#   },
#   "type": "log",
#   "namespace": -1,
#   "title": "\u062e\u0627\u0635:\u062f\u062e\u0648\u0644 \u0627\u0644\u0645\u0633\u062a\u062e\u062f\u0645",
#   "title_url": "https://ar.wikipedia.org/wiki/%D8%AE%D8%A7%D8%B5:%D8%AF%D8%AE%D9%88%D9%84_%D8%A7%D9%84%D9%85%D8%B3%D8%AA%D8%AE%D8%AF%D9%85",
#   "comment": "",
#   "timestamp": 1762714333,
#   "user": "NoWwWeR",
#   "bot": false,
#   "log_id": 0,
#   "log_type": "abusefilter",
#   "log_action": "hit",
#   "log_params": {
#     "action": "autocreateaccount",
#     "filter": "89",
#     "actions": "warn",
#     "log": 10732792
#   },
#   "log_action_comment": "NoWwWeR  \u0623\u0637\u0644\u0642 [[\u062e\u0627\u0635:\u0645\u0631\u0634\u062d \u0627\u0644\u0625\u0633\u0627\u0621\u0629/89|\u0627\u0644\u0645\u0631\u0634\u062d 89]]; \u0645\u0624\u062f\u064a\u0627 \u0627\u0644\u0641\u0639\u0644 \"autocreateaccount\" \u0641\u064a [[\u062e\u0627\u0635:\u062f\u062e\u0648\u0644 \u0627\u0644\u0645\u0633\u062a\u062e\u062f\u0645]]\u060c \u0627\u0644\u0625\u062c\u0631\u0627\u0621\u0627\u062a \u0627\u0644\u0645\u062a\u062e\u0630\u0629: \u062a\u062d\u0630\u064a\u0631 ([[\u062e\u0627\u0635:\u0633\u062c\u0644 \u0627\u0644\u0625\u0633\u0627\u0621\u0629/10732792|\u0627\u0644\u062a\u0641\u0627\u0635\u064a\u0644]])",
#   "server_url": "https://ar.wikipedia.org",
#   "server_name": "ar.wikipedia.org",
#   "server_script_path": "/w",
#   "wiki": "arwiki",
#   "parsedcomment": ""
# }

# %%
FAVORITE_TITLE = "Cristiano_Ronaldo"  # e.g. your favourite player/topic

stream.register_filter(
    server_name="fr.wikipedia.org",
    type="edit",
    namespace=0   # main article namespace, still lots of events
)

# build path for temp volume
raw_volume_path = f"/Volumes/{uc_catalog}/{uc_schema_raw_events}/{tmp_volume}"

# loop to get streaming data
while datetime.now() < stop_time:
    change = next(stream)
    
    # Use a field that definitely exists in the event data
    event_timestamp = change['meta']['dt']  # ISO 8601 timestamp
    revision_id = change.get('revision', {}).get('new', 'unknown')  # More reliable
    
    file = f"{raw_volume_path}/event_{revision_id}.json"

    # write event to file
    with open(file, 'w') as f:
        json.dump(change, f)

    # update last_event_cache with TIMESTAMP (what 'since' actually needs)
    with open(last_event_cache_path, 'w') as f:
        f.write(event_timestamp)
